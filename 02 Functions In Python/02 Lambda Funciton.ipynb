# %% [markdown]
# # Lambda Funciton

# %%
# Syntax lambda arguments: expression

addition= lambda a, b: a*b

print(type(addition))
print(addition(3,5))
# Out:
# <class 'function'>
# 15

# %%
num = lambda n :n%2==0
print(num(3))
# Out:
# False
