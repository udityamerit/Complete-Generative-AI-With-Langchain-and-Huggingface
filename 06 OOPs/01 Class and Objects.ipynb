# %%
class Car:
        pass

audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       5 bmw = Car()
#       7 print(type(audi))
# ----> 8 sjdfdsjfd
#       9 lkldkffjlj("")
#
# NameError: name 'sjdfdsjfd' is not defined

# %%
print("hello")
# Out:
# hello
