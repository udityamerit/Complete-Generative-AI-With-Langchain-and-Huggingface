# %% [markdown]
# # HTML Text Splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

# %%
html_string = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Sample Web Page</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
            margin: 20px;
            background-color: #f9f9f9;
        }
        header, section, footer {
            background: #ffffff;
            padding: 20px;
            margin-bottom: 15px;
            border-radius: 5px;
            border: 1px solid #ddd;
        }
        nav a {
            margin-right: 15px;
            text-decoration: none;
            color: #0066cc;
        }
        form {
            display: flex;
            flex-direction: column;
            max-width: 300px;
        }
        input, textarea, button {
            margin-bottom: 10px;
            padding: 8px;
        }
    </style>
</head>
<body>

    <!-- Main Navigation Header -->
    <header>
        <h1>Welcome to My Sample Website</h1>
        <nav>
            <a href="#about">About</a>
            <a href="#services">Services</a>
            <a href="#contact">Contact</a>
        </nav>
    </header>

    <!-- Main Content Section -->
    <main>
        <section id="about">
            <h2>About This Page</h2>
            <p>This is a standard paragraph element used to display text on a webpage. HTML provides the basic framework for layout structure.</p>
            <p>You can also create structured lists:</p>
            <ul>
                <li>First item in an unordered list</li>
                <li>Second item in an unordered list</li>
            </ul>
        </section>

        <!-- Interactive Form Section -->
        <section id="contact">
            <h2>Get In Touch</h2>
            <form action="#" method="POST">
                <label for="name">Name:</label>
                <input type="text" id="name" name="name" required placeholder="Your Name">

                <label for="email">Email:</label>
                <input type="email" id="email" name="email" required placeholder="Your Email">

                <label for="message">Message:</label>
                <textarea id="message" name="message" rows="4" required></textarea>

                <button type="submit">Submit Form</button>
            </form>
        </section>
    </main>

    <!-- Footer Information -->
    <footer>
        <p>&copy; 2026 Sample Company. All rights reserved.</p>
    </footer>

</body>
</html>

"""

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on)
html_header_split = html_splitter.split_text(html_string)

# %%
html_header_split
# Out:
# [Document(metadata={}, page_content='Main Navigation Header Main Content Section Footer Information'),
#  Document(metadata={'Header 1': 'Welcome to My Sample Website'}, page_content='Welcome to My Sample Website'),
#  Document(metadata={}, page_content='About  \nServices  \nContact  \nInteractive Form Section'),
#  Document(metadata={'Header 2': 'About This Page'}, page_content='About This Page'),
#  Document(metadata={'Header 2': 'About This Page'}, page_content='This is a standard paragraph element used to display text on a webpage. HTML provides the basic framework for layout structure.  \nYou can also create structured lists:  \nFirst item in an unordered list  \nSecond item in an unordered list'),
#  Document(metadata={'Header 2': 'Get In Touch'}, page_content='Get In Touch'),
#  Document(metadata={}, page_content='Name:  \nEmail:  \nMessage:  \nSubmit Form  \n© 2026 Sample Company. All rights reserved.')]

# %%
url = "https://plato.stanford.edu/entries/plato/#toc"

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on)
html_header_split = html_splitter.split_text_from_url(url)

html_header_split[1]
# Out:
# Document(metadata={'Header 1': 'Plato'}, page_content='Plato')
