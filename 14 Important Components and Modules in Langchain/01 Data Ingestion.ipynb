# %% [markdown]
# # Data Ingestion - DocumentLoaders

# %% [markdown]
# ## Text Loader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('test.txt')
loader
# Out:
# C:\Users\Uditya\AppData\Local\Temp\ipykernel_2508\903366896.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
text_doc = loader.load()
text_doc
# Out:
# [Document(metadata={'source': 'test.txt'}, page_content='Hello everyone,\n\nMy name is Uditya Narayan Tiwari, and I am currently pursuing a Bachelor of Technology in Computer Science and Engineering with a specialization in Artificial Intelligence and Machine Learning at VIT Bhopal University.\n\nI am passionate about building intelligent systems using machine learning and data-driven approaches to solve real-world problems. My primary technical skills include Python, machine learning, and data analysis, and I work extensively with libraries and frameworks such as Pandas, NumPy, Scikit-learn, and Matplotlib for developing and evaluating predictive models. I also have experience working with frameworks and tools like TensorFlow and PyTorch for deep learning, along with cloud platforms such as Google Cloud and AWS for deploying and managing scalable AI solutions.\n\nOne of my key projects is AIOPharmacy, an intelligent medicine recommendation system designed to address healthcare information overload. In this system, users can input their symptoms through text or voice, and the platform recommends relevant medications along with brand alternatives. The system leverages Sentence Transformers for deep semantic understanding and applies the Maximal Marginal Relevance algorithm to generate diverse and relevant recommendations, making complex pharmaceutical information more accessible for users.\n\nI have also worked on a breast cancer prediction project where I implemented multiple machine learning algorithms to analyze medical diagnostic data and predict whether a tumor is benign or malignant. This project involved data preprocessing, feature analysis, and model comparison using Scikit-learn to evaluate different algorithms.\n\nAnother project I worked on is credit card approval prediction, where I developed a classification model to determine whether a credit card application should be approved or rejected based on applicant data. Through this project, I gained hands-on experience in data preprocessing, feature engineering, and machine learning model evaluation.\n\nApart from projects, I am also a core team member in the Blockchain Technology R&D team and part of the tech team of the Matrix Club, where I collaborate with peers on innovative technical initiatives.\n\nI have also completed certifications in geodata processing using Python from ISRO, along with courses in machine learning and AI-based data analysis, which helped strengthen my analytical and problem-solving skills.\n\nI am currently looking for internship opportunities where I can apply my skills in machine learning, AI, and data science while continuing to learn from industry professionals and contributing to impactful projects.\n\nThank you for your time, and I look forward to connecting with you.\n')]

# %% [markdown]
# ## Reading a Pdf file

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('Uditya_Narayan_Tiwari_resume.pdf')

pdf_doc = loader.load()
pdf_doc
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T05:42:30+00:00', 'author': '', 'keywords': '', 'moddate': '2026-05-31T05:42:30+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'Uditya_Narayan_Tiwari_resume.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Uditya Narayan Tiwari\nJaunpur, Uttar Pradesh\n LinkedIn /gtbGitHub\nSUMMARY\nComputer Science Engineering student specializing in AI/ML at VIT Bhopal University with strong foundations in\nmachine learning, data analysis, and software development. Experienced in developing ML-based applications and\npredictive models and MCP Servers using Python and modern data science tools, with a keen interest in solving\nreal-world problems through AI-driven solutions\nEDUCATION\nVIT Bhopal University , Kothrikalan 2023 – Present\nB.Tech - Computer Science Engineering with AI & ML - CGPA: 9.00 VIT Bhopal University\nEXPERIENCE\nCore Member, Matrix Media Club Jan 2025 – Jul 2025\nTech Team Member VIT Bhopal University\n• Developed smart applications to improve communication between event hosts and clients.\nT echnical Member, Microsoft Learn Student Chapter Apr 2025 – Apr 2026\nTech Team Member & Community Admin VIT Bhopal University\n• Organized technical workshops and Hackathons for Microsoft technologies.\nPROJECTS\nSmart Medical Care F or Rural Areas | Python, NLP, Flask Nov 2025\n• Developed an AI-powered medicine recommendation system using NLP for symptom-based medicine suggestions.\n• Implemented Sentence Transformers with cosine similarity and MMR ranking for accurate symptom-to-medicine\nmatching.\n• Built data preprocessing pipelines and deployed the system using a Flask backend for real-time recommendations.\nCredit Card Approval Prediction | Python, Scikit-learn, Pandas Jun 2025\n• Built a machine learning classification system to predict credit card approval using applicant financial and demographic\nfeatures.\n• Conducted exploratory data analysis, feature engineering, and trained multiple models including Logistic Regression,\nDecision Tree, and Random Forest.\n• Achieved∼91% prediction accuracy with Random Forest and identified key approval drivers such as income stability and\nemployment duration.\nBreast Cancer Prediction using ML Models | Python, Scikit-learn, Jupyter Sep 2024\n• Developed a machine learning classification model using the UCI Breast Cancer dataset (569 samples, 30 features).\n• Implemented and compared 5 ML algorithms including Logistic Regression, Decision Tree, Random Forest, SVM, and\nk-NN.\n• Achieved∼97% accuracy using Random Forest and evaluated performance using ROC-AUC and confusion matrix.\nSKILLS\nLanguages: Python, C++, Java, C, SQL\nT echnologies/F rameworks:NLP, Scikit-learn, Data Preprocessing, ML Model Evaluation, MCP Servers, OOPs,\nAlgorithms & Data Structures\nDeveloper T ools: VS Code, PyCharm, IntelliJ, Canva, Kaggle\nSoft Skills: Leadership, Teamwork and Collaboration, Communication, Problem-Solving, Time Management, Multitasking\nCERTIFICATES\n• Geodata Processing using Python (IIRS, ISRO) - Feb 2024\n• AI/ML For Geodata Analysis Indian Institute of Remote Sensing (IIRS), ISRO - Sep 2024\n• IU Indianapolis Insights on Computational Data Science (IU Indianapolis) - Nov 2024\n• Final Round Qualifier, VIT Bhopal x Johns Hopkins University International Hackathon - Jan 2025\n• First prize winner in VIT Bhopal University Hackathon - Feb 2025')]

# %%
type(pdf_doc[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ## Web based loader

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader = WebBaseLoader(web_paths=["https://lilianweng.github.io/posts/2023-06-23-agent/",],
                       bs_kwargs=dict(parse_only=bs4.SoupStrainer(class_=("post-title", "post-content", "post-header")))
                       )

# %%
# loader.load()  # run this

# %%
import arxiv
import langchain
import langchain_community

print("arxiv:", arxiv.__version__)
print("langchain:", langchain.__version__)
print("langchain-community:", langchain_community.__version__)
# Out:
# arxiv: 4.0.0
# langchain: 1.3.4
# langchain-community: 0.4.2

# %%
import arxiv

search = arxiv.Search(id_list=["1706.03762"])
print(type(search))
print(dir(search))
# Out:
# <class 'arxiv.Search'>
# ['__annotations__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_url_args', 'id_list', 'max_results', 'query', 'sort_by', 'sort_order']

# %%
import arxiv

client = arxiv.Client()

search = arxiv.Search(
    id_list=["1706.03762"]
)

results = list(client.results(search))

print(results[0].title)
print(results[0].summary[:1000])
# Out:
# Attention Is All You Need
# The dominant sequence transduction models are based on complex recurrent or convolutional neural networks in an encoder-decoder configuration. The best performing models also connect the encoder and decoder through an attention mechanism. We propose a new simple network architecture, the Transformer, based solely on attention mechanisms, dispensing with recurrence and convolutions entirely. Experiments on two machine translation tasks show these models to be superior in quality while being more parallelizable and requiring significantly less time to train. Our model achieves 28.4 BLEU on the WMT 2014 English-to-German translation task, improving over the existing best results, including ensembles by over 2 BLEU. On the WMT 2014 English-to-French translation task, our model establishes a new single-model state-of-the-art BLEU score of 41.8 after training for 3.5 days on eight GPUs, a small fraction of the training costs of the best models from the literature. We show that the Transforme

# %%
from langchain_community.document_loaders import WikipediaLoader
docs = WikipediaLoader(query="Generative AI", load_max_docs=2).load()

# %%
# docs
