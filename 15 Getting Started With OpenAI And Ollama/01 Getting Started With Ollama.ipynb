# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ['LANGCHAIN_TRACING_V2'] = 'True'
os.environ['LANGCHAIN_PROJECT'] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import OllamaLLM

llm = OllamaLLM(
    model="gemma:2b"
)

response = llm.invoke("What is LangChain?")
print(response)
# Out:
# **LangChain** is a **neural network model** specifically designed for **language modeling**. It is a powerful and efficient model that can be used for a wide range of natural language processing (NLP) tasks, such as:
#
# * **Language translation**
# * **Text generation**
# * **Sentiment analysis**
# * **Named entity recognition**
# * **Text summarization**
# * **Question answering**
#
# **Key features of LangChain:**
#
# * **Parallel design:** LangChain uses a parallel architecture to speed up training and inference.
# * **Multimodal embedding:** It incorporates multiple modalities (text, audio, and image) into a single vector space.
# * **Transformer architecture:** It employs a transformer-based architecture, which is known for its effectiveness in language modeling.
# * **Self-attention mechanism:** This mechanism allows the model to focus on relevant parts of the input sequence.
# * **Dynamic weighted attention:** This mechanism dynamically weights the attention weights, ensuring that more important parts of the sequence receive more attention.
#
# **Advantages of LangChain:**
#
# * **High accuracy:** It achieves state-of-the-art performance on various NLP tasks.
# * **Fast training:** LangChain can be trained in a relatively short amount of time compared to other large language models.
# * **Parameter-efficient:** It has a relatively small number of parameters, making it efficient for resource-constrained devices.
# * **Versatile:** It can be fine-tuned on different NLP datasets to achieve optimal performance.
#
# **Disadvantages of LangChain:**
#
# * **Computational cost:** Training and inference can be computationally intensive.
# * **Ethical considerations:** Due to its capabilities, LangChain raises ethical concerns, such as bias and potential misuse.
#
# **Overall, LangChain is a powerful and efficient neural network model that is well-suited for a wide range of NLP tasks. However, it's important to consider its computational cost and ethical implications.**

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "you are an expert AI Engineer. Provided me answers based on the question"),
        ("user", "{input}")
    ]
)

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are an expert AI Engineer. Provided me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm

response = chain.invoke({'input': 'Can you tell me about the langchain'})

response
# Out:
# "Sure, I can help with that. The LangChain is an open-source platform that aims to bring **blockchain technology to human society** by building tools and resources that empower individuals to participate in the cryptoeconomy. Here's a breakdown of what the LangChain is all about:\n\n**Key features:**\n\n* **Decentralized identity (DeFi):** Users can manage and trade their crypto assets directly on the blockchain without relying on intermediaries. This allows for greater transparency and control over their finances.\n* **Non-fungible tokens (NFTs):** Users can create and trade NFTs on the LangChain, which are unique digital assets that represent ownership of real-world or virtual items.\n* **On-chain voting:** Users can participate in voting processes directly on the blockchain, contributing to the decision-making process of the platform.\n* **Interoperability:** The LangChain is designed to be interoperable with other blockchain platforms, allowing users to seamlessly transfer and trade their assets across different ecosystems.\n\n**Benefits:**\n\n* **Financial inclusion:** The LangChain aims to provide financial services to people who are excluded from traditional financial systems, such as those without a passport or credit history.\n* **Empowerment:** By giving individuals greater control over their finances, the LangChain can empower them to participate more actively in the cryptoeconomy.\n* **Transparency:** The blockchain's transparency allows for greater trust and accountability in financial transactions.\n* **Security:** The LangChain uses robust security protocols to protect user data and assets.\n\n**Challenges:**\n\n* **Scalability:** The platform is currently in its early stages of development, and its ability to handle a large number of users and transactions is a challenge.\n* **Regulation:** The LangChain is still a relatively new platform, and its future development and regulation are uncertain.\n* **User education:** Building awareness and educating people about the LangChain can be a significant hurdle.\n\n**Overall, the LangChain is a promising project with the potential to revolutionize the way people manage their finances and participate in the cryptoeconomy. However, it is important to note that the platform is still in its early stages of development, and its success and impact will depend on various factors, including its ability to overcome the challenges mentioned above.**"

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":'can you tell me about langsmith'})

# %%
response
# Out:
# "Sure, here is a comprehensive overview of Langsmith, an AI language model:\n\n**What is Langsmith?**\n\nLangsmith is a large language model, trained by Google AI, with a massive dataset of text and code. It is a conversational AI that uses natural language processing (NLP) to understand and generate human-like text.\n\n**Key Features:**\n\n* **Superhuman Language Understanding:** Langsmith can understand and generate text on a wide range of topics, including factual, literary, and conversational.\n* **Natural Language Generation:** It can create original text, translate languages, summarize documents, and answer questions.\n* **Domain-Specific Knowledge:** It has been pre-trained on a massive dataset of text and code, including Wikipedia and Google Scholar.\n* **Multimodal Intelligence:** It can process and generate text in multiple modalities, such as images, videos, and audio.\n* **Ethical and Responsible:** Langsmith is designed to be safe and responsible, and it adheres to ethical guidelines for use.\n\n**How to Use Langsmith:**\n\n* **Direct Communication:** You can interact with Langsmith directly through a conversational interface.\n* **API Integration:** It can be integrated into other applications and platforms.\n* **Cloud Access:** You can access it through Google Cloud Platform and other cloud providers.\n* **Text and Code Generation:** It can generate text and code based on specific prompts or questions.\n\n**Capabilities:**\n\n* Understanding and generating human-like text\n* Translating languages\n* Summarizing documents\n* Answering questions\n* Providing creative ideas\n* Engaging in conversations\n\n**Limitations:**\n\n* **Bias and Ethical Concerns:** Like any AI model, Langsmith can reflect biases present in its training data.\n* **Lack of Common Sense:** It may struggle with common sense or complex reasoning.\n* **Limited Emotional Understanding:** It cannot experience or express emotions like humans do.\n\n**Use Cases:**\n\n* Content creation\n* Language learning\n* Customer service\n* Research and development\n* Entertainment\n\n**Conclusion:**\n\nLangsmith is a powerful AI language model that can assist with a wide range of tasks. It is a valuable tool for text generation, translation, and other language-related applications. However, it's important to be aware of its limitations and ethical implications."
