# %% [markdown]
# # Working with file paths

# %%
import os
new_dir = "package"

os.mkdir(new_dir)
print(f"Directory '{new_dir}' created ")
# Out:
# Directory 'package' created

# %%
## listing files and directories

items = os.listdir('.')
print(items)
# Out:
# ['01 File Operations.ipynb', '02 Working With File Paths.ipynb', 'file.bin', 'package', 'test.txt']

# %%
relative_path = 'test.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\Uditya\Documents\Udemy-Courses\05 Complete Generative AI Course With Langchain and Huggingface\Complete Generative AI With Langchain and Huggingface\04 File Handalings\test.txt
